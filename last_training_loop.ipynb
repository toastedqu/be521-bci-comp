# %% [markdown]
# # Data Preparation

# %%
# %%capture
from google.colab import drive
drive.mount('/content/gdrive')
# !unzip "/content/gdrive/MyDrive/be521/final/pandora.zip" -d "/content"
# !cd "/content"

# %%
import scipy
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle
from scipy.stats import pearsonr
from scipy import signal as sig

# %%
X_train_raw = [np.load(f'X_train_{i}.npy', allow_pickle=True) for i in range(3)]
X_test_raw = [np.load(f'X_test_{i}.npy', allow_pickle=True) for i in range(3)]
Y_train_raw = [np.load(f'Y_train_{i}.npy', allow_pickle=True) for i in range(3)]
Y_test_raw = [np.load(f'Y_test_{i}.npy', allow_pickle=True) for i in range(3)]

# %%
def NumWins(length, fs, winLen, winDisp):
    return round((length/fs-winLen+winDisp)/winDisp)

def get_features(filtered_window, fs=1000):
    return np.vstack([
        np.apply_along_axis(LL, 0, filtered_window),
        np.apply_along_axis(E, 0, filtered_window),
        np.apply_along_axis(BP, 0, filtered_window, f_min=75, f_max=115),
        np.apply_along_axis(BP, 0, filtered_window, f_min=125, f_max=159),
        np.apply_along_axis(BP, 0, filtered_window, f_min=159, f_max=175),
    ]).T

def get_windowed_feats(raw_ecog, fs, window_length, window_overlap):
    data = filter_data(raw_ecog)
    n = NumWins(len(data), fs, window_length, window_overlap)
    windows = []
    for i in range(n):
        start = round(i*window_overlap*fs)
        windows.append(get_features(data[start:start+round(window_length*fs),:]))
    return np.array(windows)

# %% [markdown]
# ## Filter Data

# %%
def filter_data(raw_eeg, fs=1000):
    sos = sig.butter(8, [0.15,200],btype='bandpass',output='sos',fs=fs)
    clean_data = sig.sosfiltfilt(sos, raw_eeg, axis=0)
    return clean_data

# %% [markdown]
# ## Features

# %%
# Line Length
def LL(x):
    return np.sum(np.abs(np.ediff1d(x)))

# Area
def A(x):
    return np.linalg.norm(x, 1)

# Energy
def E(x):
    return np.sum(np.square(x))

# Bandpower
def BP(x, f_min, f_max, fs=1000):
    f, Pxx = sig.periodogram(x, fs=fs)
    i_min = np.argmax(f>f_min)-1
    i_max = np.argmax(f>f_max)-1
    return np.trapz(Pxx[i_min:i_max], f[i_min:i_max])

# %% [markdown]
# ## Execute

# %%
# RUNTIME WARNING: 30 MIN
X_train = [get_windowed_feats(X_train_raw[i], 1000, 0.1, 0.05) for i in range(3)]
X_test = [get_windowed_feats(X_test_raw[i], 1000, 0.1, 0.05) for i in range(3)]

# %%
for i in range(3):
    print(f"Subject {i+1}")
    print(f"X_train: {X_train[i].shape}")
    print(f"X_test:  {X_test[i].shape}")
    print("")
# Out:
# Subject 1
# X_train: (9019, 62, 5)
# X_test:  (2949, 62, 5)
#
# Subject 2
# X_train: (9019, 48, 5)
# X_test:  (2949, 48, 5)
#
# Subject 3
# X_train: (9019, 64, 5)
# X_test:  (2949, 64, 5)

# %%
for i in range(3):
    X_train[i] = X_train[i].reshape(X_train[i].shape[0], -1)
    X_test[i] = X_test[i].reshape(X_test[i].shape[0], -1)

    print(f"Subject {i+1}")
    print(f"X_train: {X_train[i].shape}")
    print(f"X_test:  {X_test[i].shape}")
    print("")
# Out:
# Subject 1
# X_train: (9019, 310)
# X_test:  (2949, 310)
#
# Subject 2
# X_train: (9019, 240)
# X_test:  (2949, 240)
#
# Subject 3
# X_train: (9019, 320)
# X_test:  (2949, 320)

# %% [markdown]
# ## Normalize X

# %%
from sklearn.preprocessing import StandardScaler

# Subject 1
scaler1 = StandardScaler()
X_train[0] = scaler1.fit_transform(X_train[0])
X_test[0] = scaler1.transform(X_test[0])

# Subject 2
scaler2 = StandardScaler()
X_train[1] = scaler2.fit_transform(X_train[1])
X_test[1] = scaler2.transform(X_test[1])

# # Subject 3
scaler3 = StandardScaler()
X_train[2] = scaler3.fit_transform(X_train[2])
X_test[2] = scaler3.transform(X_test[2])

# %%
from joblib import dump, load

dump(scaler1, 'scaler1.bin', compress=True)
dump(scaler2, 'scaler2.bin', compress=True)
dump(scaler3, 'scaler3.bin', compress=True)
# Out:
# ['scaler3.bin']

# %% [markdown]
# ## Downsample Y

# %%
Y_train = [sig.resample(Y_train_raw[i], NumWins(len(Y_train_raw[i]), 1000, 0.1, 0.05)) for i in range(3)]
Y_test = [sig.resample(Y_test_raw[i], NumWins(len(Y_test_raw[i]), 1000, 0.1, 0.05)) for i in range(3)]

for i in range(3):
    print(f"Subject {i+1}")
    print(f"Y_train: {Y_train[i].shape}")
    print(f"Y_test:  {Y_test[i].shape}")
    print("")
# Out:
# Subject 1
# Y_train: (9019, 5)
# Y_test:  (2949, 5)
#
# Subject 2
# Y_train: (9019, 5)
# Y_test:  (2949, 5)
#
# Subject 3
# Y_train: (9019, 5)
# Y_test:  (2949, 5)

# %% [markdown]
# ## Save & Load (to save runtime)

# %% [markdown]
# Save

# %%
for i in range(3):
    np.save(f'processed_X_train_{i}.npy', X_train[i], allow_pickle=True)
    np.save(f'processed_X_test_{i}.npy', X_test[i], allow_pickle=True)
    np.save(f'processed_Y_train_{i}.npy', Y_train[i], allow_pickle=True)
    np.save(f'processed_Y_test_{i}.npy', Y_test[i], allow_pickle=True)

# %% [markdown]
# Load

# %%
X_train = [np.load(f'processed_X_train_{i}.npy', allow_pickle=True) for i in range(3)]
X_test = [np.load(f'processed_X_test_{i}.npy', allow_pickle=True) for i in range(3)]
Y_train = [np.load(f'processed_Y_train_{i}.npy', allow_pickle=True) for i in range(3)]
Y_test = [np.load(f'processed_Y_test_{i}.npy', allow_pickle=True) for i in range(3)]

# %%
for i in range(3):
    print(f"Subject {i+1}")
    print(f"X_train: {X_train[i].shape}")
    print(f"X_test:  {X_test[i].shape}")
    print(f"Y_train: {Y_train[i].shape}")
    print(f"Y_test:  {Y_test[i].shape}")
    print("")
# Out:
# Subject 1
# X_train: (9019, 310)
# X_test:  (2949, 310)
# Y_train: (9019, 5)
# Y_test:  (2949, 5)
#
# Subject 2
# X_train: (9019, 240)
# X_test:  (2949, 240)
# Y_train: (9019, 5)
# Y_test:  (2949, 5)
#
# Subject 3
# X_train: (9019, 320)
# X_test:  (2949, 320)
# Y_train: (9019, 5)
# Y_test:  (2949, 5)

# %% [markdown]
# Concat to one

# %%
X = [np.vstack([X_train[i], X_test[i]]) for i in range(3)]
Y = [np.vstack([Y_train[i], Y_test[i]]) for i in range(3)]
Y_raw = [np.vstack([Y_train_raw[i], Y_test_raw[i]]) for i in range(3)]

# %% [markdown]
# ## Train

# %%
import lightgbm as lgb

lgb_train_data = [[lgb.Dataset(X[i], label=Y[i][:,j]) for j in range(5)] for i in range(3)]
lgb_val_data = [[lgb.Dataset(X_test[i], label=Y_test[i][:,j]) for j in range(5)] for i in range(3)]

params = {
    "learning_rate": 0.01,
    # "device_type": 'gpu',
    "max_leaves": 15,
    'max_depth': 4,
    "num_iterations": 500,
    "early_stopping_round": 10,
    "metric": 'rmse',
    "feature_fraction": 0.35,
    "bagging_fraction": 0.35,
    'bagging_freq': 1,
    'lambda_l1': 0.5,
    'lambda_l2': 0.5,
    # 'extra_trees': True,
    # 'min_data_in_leaf': 2,
    'max_bin': 25,
    'min_data_in_bin': 5,
    'random_state': 2
}

regs = []
for i in range(3):
    regs_subj = []
    for j in range(5):
        if j == 3:
            regs_subj.append(regs_subj[-1])
        else:
            reg = lgb.train(params, lgb_train_data[i][j], valid_sets=[lgb_val_data[i][j]])
            regs_subj.append(reg)
    regs.append(regs_subj)
# Out:
# /usr/local/lib/python3.9/dist-packages/lightgbm/engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# Streaming output truncated to the last 5000 lines.
# [46]	valid_0's rmse: 1.07867
# [47]	valid_0's rmse: 1.07781
# [48]	valid_0's rmse: 1.07721
# [49]	valid_0's rmse: 1.07681
# [50]	valid_0's rmse: 1.07657
# [51]	valid_0's rmse: 1.07549
# [52]	valid_0's rmse: 1.07484
# [53]	valid_0's rmse: 1.07378
# [54]	valid_0's rmse: 1.07345
# [55]	valid_0's rmse: 1.07206
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [56]	valid_0's rmse: 1.07137
# [57]	valid_0's rmse: 1.07109
# [58]	valid_0's rmse: 1.07019
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [59]	valid_0's rmse: 1.06973
# [60]	valid_0's rmse: 1.06951
# [61]	valid_0's rmse: 1.06828
# [62]	valid_0's rmse: 1.06756
# [63]	valid_0's rmse: 1.06632
# [64]	valid_0's rmse: 1.06604
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [65]	valid_0's rmse: 1.0655
# [66]	valid_0's rmse: 1.06498
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [67]	valid_0's rmse: 1.0647
# [68]	valid_0's rmse: 1.06444
# [69]	valid_0's rmse: 1.06415
# [70]	valid_0's rmse: 1.06256
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [71]	valid_0's rmse: 1.06228
# [72]	valid_0's rmse: 1.06142
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [73]	valid_0's rmse: 1.05948
# [74]	valid_0's rmse: 1.05901
# [75]	valid_0's rmse: 1.05778
# [76]	valid_0's rmse: 1.05702
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [77]	valid_0's rmse: 1.05675
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [78]	valid_0's rmse: 1.05647
# [79]	valid_0's rmse: 1.0548
# [80]	valid_0's rmse: 1.0545
# [81]	valid_0's rmse: 1.05419
# [82]	valid_0's rmse: 1.05348
# [83]	valid_0's rmse: 1.05208
# [84]	valid_0's rmse: 1.05105
# [85]	valid_0's rmse: 1.05038
# [86]	valid_0's rmse: 1.04987
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [87]	valid_0's rmse: 1.04967
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [88]	valid_0's rmse: 1.0487
# [89]	valid_0's rmse: 1.048
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [90]	valid_0's rmse: 1.04744
# [91]	valid_0's rmse: 1.04642
# [92]	valid_0's rmse: 1.04589
# [93]	valid_0's rmse: 1.04504
# [94]	valid_0's rmse: 1.04479
# [95]	valid_0's rmse: 1.04444
# [96]	valid_0's rmse: 1.044
# [97]	valid_0's rmse: 1.04332
# [98]	valid_0's rmse: 1.04295
# [99]	valid_0's rmse: 1.04153
# [100]	valid_0's rmse: 1.04084
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [101]	valid_0's rmse: 1.03978
# [102]	valid_0's rmse: 1.03921
# [103]	valid_0's rmse: 1.03897
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [104]	valid_0's rmse: 1.03807
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [105]	valid_0's rmse: 1.03726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [106]	valid_0's rmse: 1.03683
# [107]	valid_0's rmse: 1.03638
# [108]	valid_0's rmse: 1.03601
# [109]	valid_0's rmse: 1.0355
# [110]	valid_0's rmse: 1.03511
# [111]	valid_0's rmse: 1.03483
# [112]	valid_0's rmse: 1.03412
# [113]	valid_0's rmse: 1.03384
# [114]	valid_0's rmse: 1.03346
# [115]	valid_0's rmse: 1.0331
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [116]	valid_0's rmse: 1.0324
# [117]	valid_0's rmse: 1.03188
# [118]	valid_0's rmse: 1.03091
# [119]	valid_0's rmse: 1.0304
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [120]	valid_0's rmse: 1.02979
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [121]	valid_0's rmse: 1.02909
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [122]	valid_0's rmse: 1.02891
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [123]	valid_0's rmse: 1.02836
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [124]	valid_0's rmse: 1.02796
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [125]	valid_0's rmse: 1.02688
# [126]	valid_0's rmse: 1.02671
# [127]	valid_0's rmse: 1.02549
# [128]	valid_0's rmse: 1.02493
# [129]	valid_0's rmse: 1.02461
# [130]	valid_0's rmse: 1.02422
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [131]	valid_0's rmse: 1.02372
# [132]	valid_0's rmse: 1.02298
# [133]	valid_0's rmse: 1.02244
# [134]	valid_0's rmse: 1.02205
# [135]	valid_0's rmse: 1.02154
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [136]	valid_0's rmse: 1.02111
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [137]	valid_0's rmse: 1.02095
# [138]	valid_0's rmse: 1.02
# [139]	valid_0's rmse: 1.01969
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [140]	valid_0's rmse: 1.01898
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [141]	valid_0's rmse: 1.01845
# [142]	valid_0's rmse: 1.01824
# [143]	valid_0's rmse: 1.01799
# [144]	valid_0's rmse: 1.01749
# [145]	valid_0's rmse: 1.01716
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [146]	valid_0's rmse: 1.01709
# [147]	valid_0's rmse: 1.01656
# [148]	valid_0's rmse: 1.01554
# [149]	valid_0's rmse: 1.01508
# [150]	valid_0's rmse: 1.0143
# [151]	valid_0's rmse: 1.0131
# [152]	valid_0's rmse: 1.01263
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [153]	valid_0's rmse: 1.01216
# [154]	valid_0's rmse: 1.01181
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [155]	valid_0's rmse: 1.01086
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [156]	valid_0's rmse: 1.00982
# [157]	valid_0's rmse: 1.00957
# [158]	valid_0's rmse: 1.00887
# [159]	valid_0's rmse: 1.00831
# [160]	valid_0's rmse: 1.00798
# [161]	valid_0's rmse: 1.00737
# [162]	valid_0's rmse: 1.00663
# [163]	valid_0's rmse: 1.00633
# [164]	valid_0's rmse: 1.00598
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [165]	valid_0's rmse: 1.00513
# [166]	valid_0's rmse: 1.00465
# [167]	valid_0's rmse: 1.00389
# [168]	valid_0's rmse: 1.00307
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [169]	valid_0's rmse: 1.00265
# [170]	valid_0's rmse: 1.00226
# [171]	valid_0's rmse: 1.00158
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [172]	valid_0's rmse: 1.00105
# [173]	valid_0's rmse: 1.00065
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [174]	valid_0's rmse: 1.00003
# [175]	valid_0's rmse: 0.999776
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [176]	valid_0's rmse: 0.999262
# [177]	valid_0's rmse: 0.998698
# [178]	valid_0's rmse: 0.998042
# [179]	valid_0's rmse: 0.997738
# [180]	valid_0's rmse: 0.997524
# [181]	valid_0's rmse: 0.996683
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [182]	valid_0's rmse: 0.996479
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [183]	valid_0's rmse: 0.996076
# [184]	valid_0's rmse: 0.995142
# [185]	valid_0's rmse: 0.994197
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [186]	valid_0's rmse: 0.994039
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [187]	valid_0's rmse: 0.993592
# [188]	valid_0's rmse: 0.993017
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [189]	valid_0's rmse: 0.99178
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [190]	valid_0's rmse: 0.991641
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [191]	valid_0's rmse: 0.991207
# [192]	valid_0's rmse: 0.990932
# [193]	valid_0's rmse: 0.990583
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [194]	valid_0's rmse: 0.990404
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [195]	valid_0's rmse: 0.989791
# [196]	valid_0's rmse: 0.989256
# [197]	valid_0's rmse: 0.988911
# [198]	valid_0's rmse: 0.988686
# [199]	valid_0's rmse: 0.987914
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [200]	valid_0's rmse: 0.987744
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [201]	valid_0's rmse: 0.987349
# [202]	valid_0's rmse: 0.98692
# [203]	valid_0's rmse: 0.9865
# [204]	valid_0's rmse: 0.986031
# [205]	valid_0's rmse: 0.98587
# [206]	valid_0's rmse: 0.985371
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [207]	valid_0's rmse: 0.985106
# [208]	valid_0's rmse: 0.984516
# [209]	valid_0's rmse: 0.984035
# [210]	valid_0's rmse: 0.983811
# [211]	valid_0's rmse: 0.983412
# [212]	valid_0's rmse: 0.983197
# [213]	valid_0's rmse: 0.981988
# [214]	valid_0's rmse: 0.981629
# [215]	valid_0's rmse: 0.981432
# [216]	valid_0's rmse: 0.981258
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [217]	valid_0's rmse: 0.98079
# [218]	valid_0's rmse: 0.980613
# [219]	valid_0's rmse: 0.980104
# [220]	valid_0's rmse: 0.979474
# [221]	valid_0's rmse: 0.978553
# [222]	valid_0's rmse: 0.978492
# [223]	valid_0's rmse: 0.978137
# [224]	valid_0's rmse: 0.977994
# [225]	valid_0's rmse: 0.977361
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [226]	valid_0's rmse: 0.97706
# [227]	valid_0's rmse: 0.976807
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [228]	valid_0's rmse: 0.976197
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [229]	valid_0's rmse: 0.975859
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [230]	valid_0's rmse: 0.97556
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [231]	valid_0's rmse: 0.975402
# [232]	valid_0's rmse: 0.975078
# [233]	valid_0's rmse: 0.974782
# [234]	valid_0's rmse: 0.97463
# [235]	valid_0's rmse: 0.974243
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [236]	valid_0's rmse: 0.973637
# [237]	valid_0's rmse: 0.973001
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [238]	valid_0's rmse: 0.972724
# [239]	valid_0's rmse: 0.9724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [240]	valid_0's rmse: 0.97186
# [241]	valid_0's rmse: 0.971627
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [242]	valid_0's rmse: 0.970824
# [243]	valid_0's rmse: 0.970448
# [244]	valid_0's rmse: 0.969976
# [245]	valid_0's rmse: 0.969205
# [246]	valid_0's rmse: 0.968937
# [247]	valid_0's rmse: 0.96875
# [248]	valid_0's rmse: 0.968112
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [249]	valid_0's rmse: 0.967483
# [250]	valid_0's rmse: 0.967115
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [251]	valid_0's rmse: 0.966934
# [252]	valid_0's rmse: 0.966715
# [253]	valid_0's rmse: 0.9664
# [254]	valid_0's rmse: 0.965813
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [255]	valid_0's rmse: 0.965619
# [256]	valid_0's rmse: 0.965052
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [257]	valid_0's rmse: 0.964846
# [258]	valid_0's rmse: 0.964608
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [259]	valid_0's rmse: 0.96437
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [260]	valid_0's rmse: 0.963988
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [261]	valid_0's rmse: 0.963757
# [262]	valid_0's rmse: 0.963301
# [263]	valid_0's rmse: 0.962952
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [264]	valid_0's rmse: 0.962427
# [265]	valid_0's rmse: 0.96223
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [266]	valid_0's rmse: 0.962107
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [267]	valid_0's rmse: 0.961688
# [268]	valid_0's rmse: 0.961166
# [269]	valid_0's rmse: 0.960638
# [270]	valid_0's rmse: 0.959751
# [271]	valid_0's rmse: 0.959592
# [272]	valid_0's rmse: 0.959271
# [273]	valid_0's rmse: 0.958859
# [274]	valid_0's rmse: 0.958478
# [275]	valid_0's rmse: 0.95822
# [276]	valid_0's rmse: 0.95791
# [277]	valid_0's rmse: 0.957189
# [278]	valid_0's rmse: 0.956486
# [279]	valid_0's rmse: 0.956343
# [280]	valid_0's rmse: 0.955899
# [281]	valid_0's rmse: 0.955618
# [282]	valid_0's rmse: 0.955271
# [283]	valid_0's rmse: 0.955056
# [284]	valid_0's rmse: 0.954561
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [285]	valid_0's rmse: 0.953625
# [286]	valid_0's rmse: 0.953291
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [287]	valid_0's rmse: 0.953016
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [288]	valid_0's rmse: 0.952788
# [289]	valid_0's rmse: 0.952276
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [290]	valid_0's rmse: 0.951828
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [291]	valid_0's rmse: 0.951353
# [292]	valid_0's rmse: 0.950862
# [293]	valid_0's rmse: 0.950561
# [294]	valid_0's rmse: 0.950341
# [295]	valid_0's rmse: 0.950087
# [296]	valid_0's rmse: 0.949874
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [297]	valid_0's rmse: 0.949561
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [298]	valid_0's rmse: 0.949275
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [299]	valid_0's rmse: 0.948738
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [300]	valid_0's rmse: 0.948426
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [301]	valid_0's rmse: 0.948199
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [302]	valid_0's rmse: 0.947819
# [303]	valid_0's rmse: 0.947522
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [304]	valid_0's rmse: 0.947297
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [305]	valid_0's rmse: 0.947091
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [306]	valid_0's rmse: 0.946952
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [307]	valid_0's rmse: 0.946895
# [308]	valid_0's rmse: 0.946139
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [309]	valid_0's rmse: 0.945679
# [310]	valid_0's rmse: 0.944901
# [311]	valid_0's rmse: 0.944739
# [312]	valid_0's rmse: 0.944559
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [313]	valid_0's rmse: 0.944275
# [314]	valid_0's rmse: 0.943983
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [315]	valid_0's rmse: 0.943799
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [316]	valid_0's rmse: 0.943213
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [317]	valid_0's rmse: 0.942822
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [318]	valid_0's rmse: 0.942552
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [319]	valid_0's rmse: 0.942348
# [320]	valid_0's rmse: 0.942092
# [321]	valid_0's rmse: 0.941526
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [322]	valid_0's rmse: 0.94093
# [323]	valid_0's rmse: 0.940733
# [324]	valid_0's rmse: 0.94016
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [325]	valid_0's rmse: 0.939893
# [326]	valid_0's rmse: 0.939637
# [327]	valid_0's rmse: 0.939063
# [328]	valid_0's rmse: 0.938792
# [329]	valid_0's rmse: 0.938438
# [330]	valid_0's rmse: 0.93818
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [331]	valid_0's rmse: 0.938073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [332]	valid_0's rmse: 0.937584
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [333]	valid_0's rmse: 0.93718
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [334]	valid_0's rmse: 0.936877
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [335]	valid_0's rmse: 0.936721
# [336]	valid_0's rmse: 0.936384
# [337]	valid_0's rmse: 0.935968
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [338]	valid_0's rmse: 0.935757
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [339]	valid_0's rmse: 0.935423
# [340]	valid_0's rmse: 0.935033
# [341]	valid_0's rmse: 0.934892
# [342]	valid_0's rmse: 0.934663
# [343]	valid_0's rmse: 0.934439
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [344]	valid_0's rmse: 0.93429
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [345]	valid_0's rmse: 0.933886
# [346]	valid_0's rmse: 0.933241
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [347]	valid_0's rmse: 0.933153
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [348]	valid_0's rmse: 0.932705
# [349]	valid_0's rmse: 0.932551
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [350]	valid_0's rmse: 0.931597
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [351]	valid_0's rmse: 0.931134
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [352]	valid_0's rmse: 0.930671
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [353]	valid_0's rmse: 0.93043
# [354]	valid_0's rmse: 0.930284
# [355]	valid_0's rmse: 0.929943
# [356]	valid_0's rmse: 0.929617
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [357]	valid_0's rmse: 0.929352
# [358]	valid_0's rmse: 0.929119
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [359]	valid_0's rmse: 0.928776
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [360]	valid_0's rmse: 0.928646
# [361]	valid_0's rmse: 0.928479
# [362]	valid_0's rmse: 0.928328
# [363]	valid_0's rmse: 0.928153
# [364]	valid_0's rmse: 0.927606
# [365]	valid_0's rmse: 0.92724
# [366]	valid_0's rmse: 0.926945
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [367]	valid_0's rmse: 0.926616
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [368]	valid_0's rmse: 0.926493
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [369]	valid_0's rmse: 0.926198
# [370]	valid_0's rmse: 0.925895
# [371]	valid_0's rmse: 0.925535
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [372]	valid_0's rmse: 0.925538
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [373]	valid_0's rmse: 0.925286
# [374]	valid_0's rmse: 0.925163
# [375]	valid_0's rmse: 0.924842
# [376]	valid_0's rmse: 0.924477
# [377]	valid_0's rmse: 0.924062
# [378]	valid_0's rmse: 0.923862
# [379]	valid_0's rmse: 0.923515
# [380]	valid_0's rmse: 0.923351
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [381]	valid_0's rmse: 0.922982
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [382]	valid_0's rmse: 0.922672
# [383]	valid_0's rmse: 0.922459
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [384]	valid_0's rmse: 0.922107
# [385]	valid_0's rmse: 0.921863
# [386]	valid_0's rmse: 0.921243
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [387]	valid_0's rmse: 0.921142
# [388]	valid_0's rmse: 0.920841
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [389]	valid_0's rmse: 0.92068
# [390]	valid_0's rmse: 0.920196
# [391]	valid_0's rmse: 0.919696
# [392]	valid_0's rmse: 0.919492
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [393]	valid_0's rmse: 0.919337
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [394]	valid_0's rmse: 0.919295
# [395]	valid_0's rmse: 0.918713
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [396]	valid_0's rmse: 0.918514
# [397]	valid_0's rmse: 0.918186
# [398]	valid_0's rmse: 0.918007
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [399]	valid_0's rmse: 0.917927
# [400]	valid_0's rmse: 0.917455
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [401]	valid_0's rmse: 0.917363
# [402]	valid_0's rmse: 0.916936
# [403]	valid_0's rmse: 0.916445
# [404]	valid_0's rmse: 0.916228
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [405]	valid_0's rmse: 0.916094
# [406]	valid_0's rmse: 0.915832
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [407]	valid_0's rmse: 0.915668
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [408]	valid_0's rmse: 0.915613
# [409]	valid_0's rmse: 0.915279
# [410]	valid_0's rmse: 0.91513
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [411]	valid_0's rmse: 0.914878
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [412]	valid_0's rmse: 0.914775
# [413]	valid_0's rmse: 0.914374
# [414]	valid_0's rmse: 0.914187
# [415]	valid_0's rmse: 0.913952
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [416]	valid_0's rmse: 0.913715
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [417]	valid_0's rmse: 0.913532
# [418]	valid_0's rmse: 0.913369
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [419]	valid_0's rmse: 0.913154
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [420]	valid_0's rmse: 0.913117
# [421]	valid_0's rmse: 0.91295
# [422]	valid_0's rmse: 0.912711
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [423]	valid_0's rmse: 0.912433
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [424]	valid_0's rmse: 0.91235
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [425]	valid_0's rmse: 0.912204
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [426]	valid_0's rmse: 0.912033
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [427]	valid_0's rmse: 0.911294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [428]	valid_0's rmse: 0.911195
# [429]	valid_0's rmse: 0.91092
# [430]	valid_0's rmse: 0.910553
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [431]	valid_0's rmse: 0.910471
# [432]	valid_0's rmse: 0.910154
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [433]	valid_0's rmse: 0.909961
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [434]	valid_0's rmse: 0.909796
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [435]	valid_0's rmse: 0.909722
# [436]	valid_0's rmse: 0.909433
# [437]	valid_0's rmse: 0.909101
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [438]	valid_0's rmse: 0.90879
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [439]	valid_0's rmse: 0.908529
# [440]	valid_0's rmse: 0.908434
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [441]	valid_0's rmse: 0.908276
# [442]	valid_0's rmse: 0.908136
# [443]	valid_0's rmse: 0.907829
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [444]	valid_0's rmse: 0.907523
# [445]	valid_0's rmse: 0.907231
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [446]	valid_0's rmse: 0.907096
# [447]	valid_0's rmse: 0.906847
# [448]	valid_0's rmse: 0.9065
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [449]	valid_0's rmse: 0.906377
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [450]	valid_0's rmse: 0.906063
# [451]	valid_0's rmse: 0.905658
# [452]	valid_0's rmse: 0.905418
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [453]	valid_0's rmse: 0.905413
# [454]	valid_0's rmse: 0.905386
# [455]	valid_0's rmse: 0.905174
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [456]	valid_0's rmse: 0.904643
# [457]	valid_0's rmse: 0.904466
# [458]	valid_0's rmse: 0.904369
# [459]	valid_0's rmse: 0.903739
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [460]	valid_0's rmse: 0.903557
# [461]	valid_0's rmse: 0.902964
# [462]	valid_0's rmse: 0.902821
# [463]	valid_0's rmse: 0.902305
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [464]	valid_0's rmse: 0.901962
# [465]	valid_0's rmse: 0.901798
# [466]	valid_0's rmse: 0.901564
# [467]	valid_0's rmse: 0.900894
# [468]	valid_0's rmse: 0.900409
# [469]	valid_0's rmse: 0.900198
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [470]	valid_0's rmse: 0.900164
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [471]	valid_0's rmse: 0.900007
# [472]	valid_0's rmse: 0.899586
# [473]	valid_0's rmse: 0.899411
# [474]	valid_0's rmse: 0.899178
# [475]	valid_0's rmse: 0.898995
# [476]	valid_0's rmse: 0.898757
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [477]	valid_0's rmse: 0.898597
# [478]	valid_0's rmse: 0.898385
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [479]	valid_0's rmse: 0.898203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [480]	valid_0's rmse: 0.897963
# [481]	valid_0's rmse: 0.897542
# [482]	valid_0's rmse: 0.897358
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [483]	valid_0's rmse: 0.897087
# [484]	valid_0's rmse: 0.897001
# [485]	valid_0's rmse: 0.89685
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [486]	valid_0's rmse: 0.896667
# [487]	valid_0's rmse: 0.896571
# [488]	valid_0's rmse: 0.896386
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [489]	valid_0's rmse: 0.896179
# [490]	valid_0's rmse: 0.895932
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [491]	valid_0's rmse: 0.895789
# [492]	valid_0's rmse: 0.894963
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [493]	valid_0's rmse: 0.894662
# [494]	valid_0's rmse: 0.894636
# [495]	valid_0's rmse: 0.894403
# [496]	valid_0's rmse: 0.894118
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [497]	valid_0's rmse: 0.893971
# [498]	valid_0's rmse: 0.893698
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [499]	valid_0's rmse: 0.893353
# [500]	valid_0's rmse: 0.893228
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's rmse: 0.893228
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.028004 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6000
# [LightGBM] [Info] Number of data points in the train set: 11968, number of used features: 240
# [LightGBM] [Info] Start training from score 0.006615
# [1]	valid_0's rmse: 1.04815
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's rmse: 1.04724
# [3]	valid_0's rmse: 1.04611
# [4]	valid_0's rmse: 1.04546
# [5]	valid_0's rmse: 1.04457
# [6]	valid_0's rmse: 1.04392
# [7]	valid_0's rmse: 1.04298
# [8]	valid_0's rmse: 1.04215
# [9]	valid_0's rmse: 1.04131
# [10]	valid_0's rmse: 1.04077
# [11]	valid_0's rmse: 1.03973
# [12]	valid_0's rmse: 1.03902
# [13]	valid_0's rmse: 1.03817
# [14]	valid_0's rmse: 1.03729
# [15]	valid_0's rmse: 1.03626
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid_0's rmse: 1.03547
# [17]	valid_0's rmse: 1.03469
# [18]	valid_0's rmse: 1.03407
# [19]	valid_0's rmse: 1.03271
# [20]	valid_0's rmse: 1.03203
# [21]	valid_0's rmse: 1.0312
# [22]	valid_0's rmse: 1.03062
# [23]	valid_0's rmse: 1.02975
# [24]	valid_0's rmse: 1.02888
# [25]	valid_0's rmse: 1.02806
# [26]	valid_0's rmse: 1.02744
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid_0's rmse: 1.02668
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid_0's rmse: 1.02603
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid_0's rmse: 1.02517
# [30]	valid_0's rmse: 1.024
# [31]	valid_0's rmse: 1.02328
# [32]	valid_0's rmse: 1.02282
# [33]	valid_0's rmse: 1.02225
# [34]	valid_0's rmse: 1.02141
# [35]	valid_0's rmse: 1.02047
# [36]	valid_0's rmse: 1.01969
# [37]	valid_0's rmse: 1.01909
# [38]	valid_0's rmse: 1.01822
# [39]	valid_0's rmse: 1.01758
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	valid_0's rmse: 1.01691
# [41]	valid_0's rmse: 1.01614
# [42]	valid_0's rmse: 1.01555
# [43]	valid_0's rmse: 1.01484
# [44]	valid_0's rmse: 1.01414
# [45]	valid_0's rmse: 1.01366
# [46]	valid_0's rmse: 1.01299
# [47]	valid_0's rmse: 1.01247
# [48]	valid_0's rmse: 1.0118
# [49]	valid_0's rmse: 1.01115
# [50]	valid_0's rmse: 1.01048
# [51]	valid_0's rmse: 1.00989
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [52]	valid_0's rmse: 1.00906
# [53]	valid_0's rmse: 1.00857
# [54]	valid_0's rmse: 1.00818
# [55]	valid_0's rmse: 1.0076
# [56]	valid_0's rmse: 1.00711
# [57]	valid_0's rmse: 1.00655
# [58]	valid_0's rmse: 1.006
# [59]	valid_0's rmse: 1.00553
# [60]	valid_0's rmse: 1.0047
# [61]	valid_0's rmse: 1.00407
# [62]	valid_0's rmse: 1.0036
# [63]	valid_0's rmse: 1.00296
# [64]	valid_0's rmse: 1.00253
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [65]	valid_0's rmse: 1.00207
# [66]	valid_0's rmse: 1.00158
# [67]	valid_0's rmse: 1.00118
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [68]	valid_0's rmse: 1.0006
# [69]	valid_0's rmse: 1.00005
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [70]	valid_0's rmse: 0.999397
# [71]	valid_0's rmse: 0.999012
# [72]	valid_0's rmse: 0.998202
# [73]	valid_0's rmse: 0.997546
# [74]	valid_0's rmse: 0.997037
# [75]	valid_0's rmse: 0.996423
# [76]	valid_0's rmse: 0.995736
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [77]	valid_0's rmse: 0.995599
# [78]	valid_0's rmse: 0.995288
# [79]	valid_0's rmse: 0.994779
# [80]	valid_0's rmse: 0.994346
# [81]	valid_0's rmse: 0.99382
# [82]	valid_0's rmse: 0.993315
# [83]	valid_0's rmse: 0.992694
# [84]	valid_0's rmse: 0.992196
# [85]	valid_0's rmse: 0.991607
# [86]	valid_0's rmse: 0.990971
# [87]	valid_0's rmse: 0.99061
# [88]	valid_0's rmse: 0.990028
# [89]	valid_0's rmse: 0.989343
# [90]	valid_0's rmse: 0.988899
# [91]	valid_0's rmse: 0.988395
# [92]	valid_0's rmse: 0.988156
# [93]	valid_0's rmse: 0.987688
# [94]	valid_0's rmse: 0.987245
# [95]	valid_0's rmse: 0.986867
# [96]	valid_0's rmse: 0.986489
# [97]	valid_0's rmse: 0.986141
# [98]	valid_0's rmse: 0.985898
# [99]	valid_0's rmse: 0.985115
# [100]	valid_0's rmse: 0.984829
# [101]	valid_0's rmse: 0.984201
# [102]	valid_0's rmse: 0.98379
# [103]	valid_0's rmse: 0.983471
# [104]	valid_0's rmse: 0.983195
# [105]	valid_0's rmse: 0.982472
# [106]	valid_0's rmse: 0.981799
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [107]	valid_0's rmse: 0.981241
# [108]	valid_0's rmse: 0.980819
# [109]	valid_0's rmse: 0.980272
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [110]	valid_0's rmse: 0.979798
# [111]	valid_0's rmse: 0.979402
# [112]	valid_0's rmse: 0.97889
# [113]	valid_0's rmse: 0.97831
# [114]	valid_0's rmse: 0.977937
# [115]	valid_0's rmse: 0.977536
# [116]	valid_0's rmse: 0.977153
# [117]	valid_0's rmse: 0.9768
# [118]	valid_0's rmse: 0.976337
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [119]	valid_0's rmse: 0.975902
# [120]	valid_0's rmse: 0.975448
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [121]	valid_0's rmse: 0.975191
# [122]	valid_0's rmse: 0.974859
# [123]	valid_0's rmse: 0.974483
# [124]	valid_0's rmse: 0.974065
# [125]	valid_0's rmse: 0.973441
# [126]	valid_0's rmse: 0.973047
# [127]	valid_0's rmse: 0.972575
# [128]	valid_0's rmse: 0.972155
# [129]	valid_0's rmse: 0.971737
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [130]	valid_0's rmse: 0.971344
# [131]	valid_0's rmse: 0.970937
# [132]	valid_0's rmse: 0.970317
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [133]	valid_0's rmse: 0.970028
# [134]	valid_0's rmse: 0.969385
# [135]	valid_0's rmse: 0.968822
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [136]	valid_0's rmse: 0.968414
# [137]	valid_0's rmse: 0.968068
# [138]	valid_0's rmse: 0.967614
# [139]	valid_0's rmse: 0.967239
# [140]	valid_0's rmse: 0.966763
# [141]	valid_0's rmse: 0.96639
# [142]	valid_0's rmse: 0.965945
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [143]	valid_0's rmse: 0.96565
# [144]	valid_0's rmse: 0.965452
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [145]	valid_0's rmse: 0.965303
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [146]	valid_0's rmse: 0.964983
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [147]	valid_0's rmse: 0.964742
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [148]	valid_0's rmse: 0.964438
# [149]	valid_0's rmse: 0.964157
# [150]	valid_0's rmse: 0.963793
# [151]	valid_0's rmse: 0.963452
# [152]	valid_0's rmse: 0.963185
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [153]	valid_0's rmse: 0.962966
# [154]	valid_0's rmse: 0.962499
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [155]	valid_0's rmse: 0.962057
# [156]	valid_0's rmse: 0.96164
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [157]	valid_0's rmse: 0.961163
# [158]	valid_0's rmse: 0.960809
# [159]	valid_0's rmse: 0.960545
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [160]	valid_0's rmse: 0.960218
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [161]	valid_0's rmse: 0.959856
# [162]	valid_0's rmse: 0.959464
# [163]	valid_0's rmse: 0.958994
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [164]	valid_0's rmse: 0.958534
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [165]	valid_0's rmse: 0.958192
# [166]	valid_0's rmse: 0.957704
# [167]	valid_0's rmse: 0.957308
# [168]	valid_0's rmse: 0.956892
# [169]	valid_0's rmse: 0.956559
# [170]	valid_0's rmse: 0.956119
# [171]	valid_0's rmse: 0.955747
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [172]	valid_0's rmse: 0.955509
# [173]	valid_0's rmse: 0.955217
# [174]	valid_0's rmse: 0.954686
# [175]	valid_0's rmse: 0.954325
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [176]	valid_0's rmse: 0.954039
# [177]	valid_0's rmse: 0.953573
# [178]	valid_0's rmse: 0.953377
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [179]	valid_0's rmse: 0.95319
# [180]	valid_0's rmse: 0.952956
# [181]	valid_0's rmse: 0.952623
# [182]	valid_0's rmse: 0.952382
# [183]	valid_0's rmse: 0.95214
# [184]	valid_0's rmse: 0.951779
# [185]	valid_0's rmse: 0.951244
# [186]	valid_0's rmse: 0.951008
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [187]	valid_0's rmse: 0.950592
# [188]	valid_0's rmse: 0.950198
# [189]	valid_0's rmse: 0.949899
# [190]	valid_0's rmse: 0.949537
# [191]	valid_0's rmse: 0.949239
# [192]	valid_0's rmse: 0.948881
# [193]	valid_0's rmse: 0.948681
# [194]	valid_0's rmse: 0.948433
# [195]	valid_0's rmse: 0.94814
# [196]	valid_0's rmse: 0.947939
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [197]	valid_0's rmse: 0.947641
# [198]	valid_0's rmse: 0.94741
# [199]	valid_0's rmse: 0.947019
# [200]	valid_0's rmse: 0.946809
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [201]	valid_0's rmse: 0.946538
# [202]	valid_0's rmse: 0.946305
# [203]	valid_0's rmse: 0.945882
# [204]	valid_0's rmse: 0.945602
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [205]	valid_0's rmse: 0.945432
# [206]	valid_0's rmse: 0.945112
# [207]	valid_0's rmse: 0.944965
# [208]	valid_0's rmse: 0.944693
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [209]	valid_0's rmse: 0.944411
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [210]	valid_0's rmse: 0.944129
# [211]	valid_0's rmse: 0.943727
# [212]	valid_0's rmse: 0.943304
# [213]	valid_0's rmse: 0.943023
# [214]	valid_0's rmse: 0.942641
# [215]	valid_0's rmse: 0.942375
# [216]	valid_0's rmse: 0.942199
# [217]	valid_0's rmse: 0.942063
# [218]	valid_0's rmse: 0.941808
# [219]	valid_0's rmse: 0.941594
# [220]	valid_0's rmse: 0.941174
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [221]	valid_0's rmse: 0.940704
# [222]	valid_0's rmse: 0.940463
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [223]	valid_0's rmse: 0.940255
# [224]	valid_0's rmse: 0.940003
# [225]	valid_0's rmse: 0.939662
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [226]	valid_0's rmse: 0.939462
# [227]	valid_0's rmse: 0.93925
# [228]	valid_0's rmse: 0.938903
# [229]	valid_0's rmse: 0.938519
# [230]	valid_0's rmse: 0.938321
# [231]	valid_0's rmse: 0.938065
# [232]	valid_0's rmse: 0.937983
# [233]	valid_0's rmse: 0.937714
# [234]	valid_0's rmse: 0.937412
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [235]	valid_0's rmse: 0.937065
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [236]	valid_0's rmse: 0.93669
# [237]	valid_0's rmse: 0.936304
# [238]	valid_0's rmse: 0.935954
# [239]	valid_0's rmse: 0.935654
# [240]	valid_0's rmse: 0.935243
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [241]	valid_0's rmse: 0.93506
# [242]	valid_0's rmse: 0.934747
# [243]	valid_0's rmse: 0.934236
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [244]	valid_0's rmse: 0.933999
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [245]	valid_0's rmse: 0.933708
# [246]	valid_0's rmse: 0.933411
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [247]	valid_0's rmse: 0.933185
# [248]	valid_0's rmse: 0.932896
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [249]	valid_0's rmse: 0.932601
# [250]	valid_0's rmse: 0.932357
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [251]	valid_0's rmse: 0.932161
# [252]	valid_0's rmse: 0.931948
# [253]	valid_0's rmse: 0.931489
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [254]	valid_0's rmse: 0.931274
# [255]	valid_0's rmse: 0.930961
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [256]	valid_0's rmse: 0.930533
# [257]	valid_0's rmse: 0.930225
# [258]	valid_0's rmse: 0.930004
# [259]	valid_0's rmse: 0.92974
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [260]	valid_0's rmse: 0.929496
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [261]	valid_0's rmse: 0.92927
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [262]	valid_0's rmse: 0.929041
# [263]	valid_0's rmse: 0.928959
# [264]	valid_0's rmse: 0.928593
# [265]	valid_0's rmse: 0.92848
# [266]	valid_0's rmse: 0.928335
# [267]	valid_0's rmse: 0.928095
# [268]	valid_0's rmse: 0.927782
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [269]	valid_0's rmse: 0.927274
# [270]	valid_0's rmse: 0.926913
# [271]	valid_0's rmse: 0.926691
# [272]	valid_0's rmse: 0.92637
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [273]	valid_0's rmse: 0.926252
# [274]	valid_0's rmse: 0.925957
# [275]	valid_0's rmse: 0.925737
# [276]	valid_0's rmse: 0.925421
# [277]	valid_0's rmse: 0.924992
# [278]	valid_0's rmse: 0.924729
# [279]	valid_0's rmse: 0.924662
# [280]	valid_0's rmse: 0.924206
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [281]	valid_0's rmse: 0.923861
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [282]	valid_0's rmse: 0.923687
# [283]	valid_0's rmse: 0.92339
# [284]	valid_0's rmse: 0.922965
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [285]	valid_0's rmse: 0.922495
# [286]	valid_0's rmse: 0.922404
# [287]	valid_0's rmse: 0.922211
# [288]	valid_0's rmse: 0.922023
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [289]	valid_0's rmse: 0.921625
# [290]	valid_0's rmse: 0.921403
# [291]	valid_0's rmse: 0.921192
# [292]	valid_0's rmse: 0.920838
# [293]	valid_0's rmse: 0.920515
# [294]	valid_0's rmse: 0.920337
# [295]	valid_0's rmse: 0.920092
# [296]	valid_0's rmse: 0.919958
# [297]	valid_0's rmse: 0.919605
# [298]	valid_0's rmse: 0.919341
# [299]	valid_0's rmse: 0.919077
# [300]	valid_0's rmse: 0.91889
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [301]	valid_0's rmse: 0.918523
# [302]	valid_0's rmse: 0.918318
# [303]	valid_0's rmse: 0.918032
# [304]	valid_0's rmse: 0.917891
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [305]	valid_0's rmse: 0.917802
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [306]	valid_0's rmse: 0.917575
# [307]	valid_0's rmse: 0.917256
# [308]	valid_0's rmse: 0.917064
# [309]	valid_0's rmse: 0.916707
# [310]	valid_0's rmse: 0.916458
# [311]	valid_0's rmse: 0.916313
# [312]	valid_0's rmse: 0.916093
# [313]	valid_0's rmse: 0.915946
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [314]	valid_0's rmse: 0.915836
# [315]	valid_0's rmse: 0.915637
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [316]	valid_0's rmse: 0.915389
# [317]	valid_0's rmse: 0.915183
# [318]	valid_0's rmse: 0.914992
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [319]	valid_0's rmse: 0.914835
# [320]	valid_0's rmse: 0.914634
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [321]	valid_0's rmse: 0.914486
# [322]	valid_0's rmse: 0.914357
# [323]	valid_0's rmse: 0.914255
# [324]	valid_0's rmse: 0.9141
# [325]	valid_0's rmse: 0.913755
# [326]	valid_0's rmse: 0.913556
# [327]	valid_0's rmse: 0.913392
# [328]	valid_0's rmse: 0.913112
# [329]	valid_0's rmse: 0.912784
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [330]	valid_0's rmse: 0.912622
# [331]	valid_0's rmse: 0.912466
# [332]	valid_0's rmse: 0.912274
# [333]	valid_0's rmse: 0.912062
# [334]	valid_0's rmse: 0.91193
# [335]	valid_0's rmse: 0.911841
# [336]	valid_0's rmse: 0.911653
# [337]	valid_0's rmse: 0.911373
# [338]	valid_0's rmse: 0.911211
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [339]	valid_0's rmse: 0.911067
# [340]	valid_0's rmse: 0.910828
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [341]	valid_0's rmse: 0.910613
# [342]	valid_0's rmse: 0.910562
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [343]	valid_0's rmse: 0.910415
# [344]	valid_0's rmse: 0.910166
# [345]	valid_0's rmse: 0.909941
# [346]	valid_0's rmse: 0.909618
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [347]	valid_0's rmse: 0.909474
# [348]	valid_0's rmse: 0.90934
# [349]	valid_0's rmse: 0.909223
# [350]	valid_0's rmse: 0.90892
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [351]	valid_0's rmse: 0.90878
# [352]	valid_0's rmse: 0.908596
# [353]	valid_0's rmse: 0.908226
# [354]	valid_0's rmse: 0.908122
# [355]	valid_0's rmse: 0.907868
# [356]	valid_0's rmse: 0.90767
# [357]	valid_0's rmse: 0.907427
# [358]	valid_0's rmse: 0.907345
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [359]	valid_0's rmse: 0.907074
# [360]	valid_0's rmse: 0.906856
# [361]	valid_0's rmse: 0.906504
# [362]	valid_0's rmse: 0.906304
# [363]	valid_0's rmse: 0.906127
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [364]	valid_0's rmse: 0.905975
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [365]	valid_0's rmse: 0.905833
# [366]	valid_0's rmse: 0.905554
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [367]	valid_0's rmse: 0.905352
# [368]	valid_0's rmse: 0.905003
# [369]	valid_0's rmse: 0.904917
# [370]	valid_0's rmse: 0.904629
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [371]	valid_0's rmse: 0.904271
# [372]	valid_0's rmse: 0.90415
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [373]	valid_0's rmse: 0.903885
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [374]	valid_0's rmse: 0.903784
# [375]	valid_0's rmse: 0.903595
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [376]	valid_0's rmse: 0.903416
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [377]	valid_0's rmse: 0.903186
# [378]	valid_0's rmse: 0.902952
# [379]	valid_0's rmse: 0.902807
# [380]	valid_0's rmse: 0.902341
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [381]	valid_0's rmse: 0.902116
# [382]	valid_0's rmse: 0.901874
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [383]	valid_0's rmse: 0.901611
# [384]	valid_0's rmse: 0.901344
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [385]	valid_0's rmse: 0.901138
# [386]	valid_0's rmse: 0.900985
# [387]	valid_0's rmse: 0.90084
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [388]	valid_0's rmse: 0.900536
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [389]	valid_0's rmse: 0.900353
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [390]	valid_0's rmse: 0.900177
# [391]	valid_0's rmse: 0.899878
# [392]	valid_0's rmse: 0.899801
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [393]	valid_0's rmse: 0.899699
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [394]	valid_0's rmse: 0.89943
# [395]	valid_0's rmse: 0.899247
# [396]	valid_0's rmse: 0.898981
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [397]	valid_0's rmse: 0.898767
# [398]	valid_0's rmse: 0.898414
# [399]	valid_0's rmse: 0.898306
# [400]	valid_0's rmse: 0.898095
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [401]	valid_0's rmse: 0.897888
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [402]	valid_0's rmse: 0.897692
# [403]	valid_0's rmse: 0.897562
# [404]	valid_0's rmse: 0.897384
# [405]	valid_0's rmse: 0.897334
# [406]	valid_0's rmse: 0.897176
# [407]	valid_0's rmse: 0.897058
# [408]	valid_0's rmse: 0.896835
# [409]	valid_0's rmse: 0.89676
# [410]	valid_0's rmse: 0.896631
# [411]	valid_0's rmse: 0.896376
# [412]	valid_0's rmse: 0.896253
# [413]	valid_0's rmse: 0.89588
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [414]	valid_0's rmse: 0.895574
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [415]	valid_0's rmse: 0.895479
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [416]	valid_0's rmse: 0.895237
# [417]	valid_0's rmse: 0.895182
# [418]	valid_0's rmse: 0.894943
# [419]	valid_0's rmse: 0.894866
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [420]	valid_0's rmse: 0.894664
# [421]	valid_0's rmse: 0.894375
# [422]	valid_0's rmse: 0.894042
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [423]	valid_0's rmse: 0.893907
# [424]	valid_0's rmse: 0.893803
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [425]	valid_0's rmse: 0.893515
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [426]	valid_0's rmse: 0.893322
# [427]	valid_0's rmse: 0.893152
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [428]	valid_0's rmse: 0.892838
# [429]	valid_0's rmse: 0.892662
# [430]	valid_0's rmse: 0.892562
# [431]	valid_0's rmse: 0.892391
# [432]	valid_0's rmse: 0.892157
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [163]	valid_0's rmse: 0.979914
# [164]	valid_0's rmse: 0.979347
# [165]	valid_0's rmse: 0.978664
# [166]	valid_0's rmse: 0.978128
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [167]	valid_0's rmse: 0.977406
# [168]	valid_0's rmse: 0.977188
# [169]	valid_0's rmse: 0.976676
# [170]	valid_0's rmse: 0.97631
# [171]	valid_0's rmse: 0.975765
# [172]	valid_0's rmse: 0.975098
# [173]	valid_0's rmse: 0.974788
# [174]	valid_0's rmse: 0.974349
# [175]	valid_0's rmse: 0.973645
# [176]	valid_0's rmse: 0.973143
# [177]	valid_0's rmse: 0.972819
# [178]	valid_0's rmse: 0.972441
# [179]	valid_0's rmse: 0.972103
# [180]	valid_0's rmse: 0.97178
# [181]	valid_0's rmse: 0.971424
# [182]	valid_0's rmse: 0.970828
# [183]	valid_0's rmse: 0.970202
# [184]	valid_0's rmse: 0.969786
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [185]	valid_0's rmse: 0.969422
# [186]	valid_0's rmse: 0.968828
# [187]	valid_0's rmse: 0.968248
# [188]	valid_0's rmse: 0.967723
# [189]	valid_0's rmse: 0.967223
# [190]	valid_0's rmse: 0.966783
# [191]	valid_0's rmse: 0.96638
# [192]	valid_0's rmse: 0.966087
# [193]	valid_0's rmse: 0.965686
# [194]	valid_0's rmse: 0.965294
# [195]	valid_0's rmse: 0.964886
# [196]	valid_0's rmse: 0.964445
# [197]	valid_0's rmse: 0.963968
# [198]	valid_0's rmse: 0.963392
# [199]	valid_0's rmse: 0.962946
# [200]	valid_0's rmse: 0.962341
# [201]	valid_0's rmse: 0.961755
# [202]	valid_0's rmse: 0.961457
# [203]	valid_0's rmse: 0.961176
# [204]	valid_0's rmse: 0.9609
# [205]	valid_0's rmse: 0.960539
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [206]	valid_0's rmse: 0.960245
# [207]	valid_0's rmse: 0.959722
# [208]	valid_0's rmse: 0.959306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [209]	valid_0's rmse: 0.958799
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [210]	valid_0's rmse: 0.958426
# [211]	valid_0's rmse: 0.957872
# [212]	valid_0's rmse: 0.957609
# [213]	valid_0's rmse: 0.957101
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [214]	valid_0's rmse: 0.956738
# [215]	valid_0's rmse: 0.956169
# [216]	valid_0's rmse: 0.955761
# [217]	valid_0's rmse: 0.955294
# [218]	valid_0's rmse: 0.954767
# [219]	valid_0's rmse: 0.954421
# [220]	valid_0's rmse: 0.954059
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [221]	valid_0's rmse: 0.953579
# [222]	valid_0's rmse: 0.953001
# [223]	valid_0's rmse: 0.952492
# [224]	valid_0's rmse: 0.951893
# [225]	valid_0's rmse: 0.951686
# [226]	valid_0's rmse: 0.951038
# [227]	valid_0's rmse: 0.95068
# [228]	valid_0's rmse: 0.950385
# [229]	valid_0's rmse: 0.949885
# [230]	valid_0's rmse: 0.949264
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [231]	valid_0's rmse: 0.948697
# [232]	valid_0's rmse: 0.94832
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [233]	valid_0's rmse: 0.947797
# [234]	valid_0's rmse: 0.94744
# [235]	valid_0's rmse: 0.947003
# [236]	valid_0's rmse: 0.946696
# [237]	valid_0's rmse: 0.946338
# [238]	valid_0's rmse: 0.945908
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [239]	valid_0's rmse: 0.945524
# [240]	valid_0's rmse: 0.945099
# [241]	valid_0's rmse: 0.944883
# [242]	valid_0's rmse: 0.944555
# [243]	valid_0's rmse: 0.943964
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [244]	valid_0's rmse: 0.943591
# [245]	valid_0's rmse: 0.943194
# [246]	valid_0's rmse: 0.942799
# [247]	valid_0's rmse: 0.942366
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [248]	valid_0's rmse: 0.94188
# [249]	valid_0's rmse: 0.941207
# [250]	valid_0's rmse: 0.940747
# [251]	valid_0's rmse: 0.940453
# [252]	valid_0's rmse: 0.940084
# [253]	valid_0's rmse: 0.939568
# [254]	valid_0's rmse: 0.939259
# [255]	valid_0's rmse: 0.938931
# [256]	valid_0's rmse: 0.938576
# [257]	valid_0's rmse: 0.938269
# [258]	valid_0's rmse: 0.937919
# [259]	valid_0's rmse: 0.937621
# [260]	valid_0's rmse: 0.937251
# [261]	valid_0's rmse: 0.936986
# [262]	valid_0's rmse: 0.936609
# [263]	valid_0's rmse: 0.936245
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [264]	valid_0's rmse: 0.935864
# [265]	valid_0's rmse: 0.935352
# [266]	valid_0's rmse: 0.935116
# [267]	valid_0's rmse: 0.93462
# [268]	valid_0's rmse: 0.93425
# [269]	valid_0's rmse: 0.933934
# [270]	valid_0's rmse: 0.933646
# [271]	valid_0's rmse: 0.933235
# [272]	valid_0's rmse: 0.932817
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [273]	valid_0's rmse: 0.932351
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [274]	valid_0's rmse: 0.932117
# [275]	valid_0's rmse: 0.931536
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [276]	valid_0's rmse: 0.931148
# [277]	valid_0's rmse: 0.930789
# [278]	valid_0's rmse: 0.930398
# [279]	valid_0's rmse: 0.930027
# [280]	valid_0's rmse: 0.929635
# [281]	valid_0's rmse: 0.929341
# [282]	valid_0's rmse: 0.929148
# [283]	valid_0's rmse: 0.928795
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [284]	valid_0's rmse: 0.92857
# [285]	valid_0's rmse: 0.928231
# [286]	valid_0's rmse: 0.927902
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [287]	valid_0's rmse: 0.927495
# [288]	valid_0's rmse: 0.927221
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [289]	valid_0's rmse: 0.927056
# [290]	valid_0's rmse: 0.926712
# [291]	valid_0's rmse: 0.926454
# [292]	valid_0's rmse: 0.926262
# [293]	valid_0's rmse: 0.925995
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [294]	valid_0's rmse: 0.925629
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [295]	valid_0's rmse: 0.925336
# [296]	valid_0's rmse: 0.925044
# [297]	valid_0's rmse: 0.924763
# [298]	valid_0's rmse: 0.924517
# [299]	valid_0's rmse: 0.924255
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [300]	valid_0's rmse: 0.923882
# [301]	valid_0's rmse: 0.923614
# [302]	valid_0's rmse: 0.923291
# [303]	valid_0's rmse: 0.922943
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [304]	valid_0's rmse: 0.922625
# [305]	valid_0's rmse: 0.922272
# [306]	valid_0's rmse: 0.922159
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [307]	valid_0's rmse: 0.921977
# [308]	valid_0's rmse: 0.921779
# [309]	valid_0's rmse: 0.921388
# [310]	valid_0's rmse: 0.921236
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [311]	valid_0's rmse: 0.920988
# [312]	valid_0's rmse: 0.920734
# [313]	valid_0's rmse: 0.920462
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [314]	valid_0's rmse: 0.920183
# [315]	valid_0's rmse: 0.919907
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [316]	valid_0's rmse: 0.919629
# [317]	valid_0's rmse: 0.919277
# [318]	valid_0's rmse: 0.919037
# [319]	valid_0's rmse: 0.918695
# [320]	valid_0's rmse: 0.918505
# [321]	valid_0's rmse: 0.918271
# [322]	valid_0's rmse: 0.917967
# [323]	valid_0's rmse: 0.917742
# [324]	valid_0's rmse: 0.91741
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [325]	valid_0's rmse: 0.91701
# [326]	valid_0's rmse: 0.91664
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [327]	valid_0's rmse: 0.916489
# [328]	valid_0's rmse: 0.915975
# [329]	valid_0's rmse: 0.915529
# [330]	valid_0's rmse: 0.915359
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [331]	valid_0's rmse: 0.915086
# [332]	valid_0's rmse: 0.914813
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [333]	valid_0's rmse: 0.91458
# [334]	valid_0's rmse: 0.914263
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [335]	valid_0's rmse: 0.913972
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [336]	valid_0's rmse: 0.913753
# [337]	valid_0's rmse: 0.913521
# [338]	valid_0's rmse: 0.913285
# [339]	valid_0's rmse: 0.912938
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [340]	valid_0's rmse: 0.912592
# [341]	valid_0's rmse: 0.912326
# [342]	valid_0's rmse: 0.912073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [343]	valid_0's rmse: 0.911782
# [344]	valid_0's rmse: 0.911585
# [345]	valid_0's rmse: 0.911448
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [346]	valid_0's rmse: 0.911307
# [347]	valid_0's rmse: 0.911069
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [348]	valid_0's rmse: 0.910817
# [349]	valid_0's rmse: 0.910493
# [350]	valid_0's rmse: 0.910035
# [351]	valid_0's rmse: 0.909799
# [352]	valid_0's rmse: 0.909468
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [353]	valid_0's rmse: 0.909365
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [354]	valid_0's rmse: 0.909132
# [355]	valid_0's rmse: 0.908887
# [356]	valid_0's rmse: 0.908708
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [357]	valid_0's rmse: 0.908335
# [358]	valid_0's rmse: 0.908002
# [359]	valid_0's rmse: 0.907767
# [360]	valid_0's rmse: 0.907289
# [361]	valid_0's rmse: 0.906937
# [362]	valid_0's rmse: 0.906648
# [363]	valid_0's rmse: 0.906343
# [364]	valid_0's rmse: 0.906125
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [365]	valid_0's rmse: 0.905867
# [366]	valid_0's rmse: 0.905692
# [367]	valid_0's rmse: 0.905434
# [368]	valid_0's rmse: 0.905163
# [369]	valid_0's rmse: 0.904919
# [370]	valid_0's rmse: 0.90466
# [371]	valid_0's rmse: 0.904389
# [372]	valid_0's rmse: 0.904155
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [373]	valid_0's rmse: 0.90407
# [374]	valid_0's rmse: 0.903788
# [375]	valid_0's rmse: 0.903468
# [376]	valid_0's rmse: 0.903119
# [377]	valid_0's rmse: 0.903008
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [378]	valid_0's rmse: 0.90277
# [379]	valid_0's rmse: 0.902446
# [380]	valid_0's rmse: 0.902199
# [381]	valid_0's rmse: 0.902024
# [382]	valid_0's rmse: 0.901837
# [383]	valid_0's rmse: 0.901653
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [384]	valid_0's rmse: 0.901381
# [385]	valid_0's rmse: 0.901216
# [386]	valid_0's rmse: 0.900872
# [387]	valid_0's rmse: 0.900618
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [388]	valid_0's rmse: 0.900436
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [389]	valid_0's rmse: 0.900258
# [390]	valid_0's rmse: 0.900023
# [391]	valid_0's rmse: 0.899773
# [392]	valid_0's rmse: 0.899541
# [393]	valid_0's rmse: 0.899265
# [394]	valid_0's rmse: 0.899126
# [395]	valid_0's rmse: 0.898933
# [396]	valid_0's rmse: 0.89881
# [397]	valid_0's rmse: 0.898548
# [398]	valid_0's rmse: 0.898293
# [399]	valid_0's rmse: 0.898115
# [400]	valid_0's rmse: 0.897898
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [401]	valid_0's rmse: 0.897702
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [402]	valid_0's rmse: 0.897436
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [403]	valid_0's rmse: 0.897305
# [404]	valid_0's rmse: 0.897114
# [405]	valid_0's rmse: 0.896849
# [406]	valid_0's rmse: 0.896752
# [407]	valid_0's rmse: 0.89648
# [408]	valid_0's rmse: 0.896201
# [409]	valid_0's rmse: 0.895949
# [410]	valid_0's rmse: 0.895775
# [411]	valid_0's rmse: 0.895461
# [412]	valid_0's rmse: 0.895363
# [413]	valid_0's rmse: 0.895014
# [414]	valid_0's rmse: 0.894751
# [415]	valid_0's rmse: 0.894462
# [416]	valid_0's rmse: 0.894243
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [417]	valid_0's rmse: 0.894001
# [418]	valid_0's rmse: 0.89363
# [419]	valid_0's rmse: 0.893455
# [420]	valid_0's rmse: 0.893154
# [421]	valid_0's rmse: 0.89292
# [422]	valid_0's rmse: 0.892721
# [423]	valid_0's rmse: 0.892481
# [424]	valid_0's rmse: 0.892287
# [425]	valid_0's rmse: 0.892046
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [426]	valid_0's rmse: 0.891798
# [427]	valid_0's rmse: 0.891537
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [428]	valid_0's rmse: 0.891343
# [429]	valid_0's rmse: 0.89114
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [430]	valid_0's rmse: 0.890925
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [431]	valid_0's rmse: 0.890814
# [432]	valid_0's rmse: 0.89058
# [433]	valid_0's rmse: 0.890418
# [434]	valid_0's rmse: 0.890147
# [435]	valid_0's rmse: 0.889971
# [436]	valid_0's rmse: 0.889679
# [437]	valid_0's rmse: 0.889347
# [438]	valid_0's rmse: 0.889113
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [439]	valid_0's rmse: 0.888959
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [440]	valid_0's rmse: 0.888759
# [441]	valid_0's rmse: 0.888583
# [442]	valid_0's rmse: 0.888478
# [443]	valid_0's rmse: 0.888173
# [444]	valid_0's rmse: 0.887915
# [445]	valid_0's rmse: 0.887694
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [446]	valid_0's rmse: 0.887501
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [447]	valid_0's rmse: 0.887318
# [448]	valid_0's rmse: 0.887057
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [449]	valid_0's rmse: 0.886955
# [450]	valid_0's rmse: 0.886655
# [451]	valid_0's rmse: 0.886432
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [452]	valid_0's rmse: 0.886263
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [453]	valid_0's rmse: 0.88604
# [454]	valid_0's rmse: 0.885726
# [455]	valid_0's rmse: 0.885579
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [456]	valid_0's rmse: 0.885423
# [457]	valid_0's rmse: 0.885243
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [458]	valid_0's rmse: 0.885053
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [459]	valid_0's rmse: 0.884744
# [460]	valid_0's rmse: 0.88443
# [461]	valid_0's rmse: 0.884187
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [462]	valid_0's rmse: 0.883927
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [463]	valid_0's rmse: 0.883733
# [464]	valid_0's rmse: 0.88349
# [465]	valid_0's rmse: 0.883278
# [466]	valid_0's rmse: 0.883014
# [467]	valid_0's rmse: 0.882715
# [468]	valid_0's rmse: 0.882431
# [469]	valid_0's rmse: 0.882205
# [470]	valid_0's rmse: 0.881985
# [471]	valid_0's rmse: 0.881761
# [472]	valid_0's rmse: 0.881573
# [473]	valid_0's rmse: 0.881418
# [474]	valid_0's rmse: 0.881168
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [475]	valid_0's rmse: 0.881044
# [476]	valid_0's rmse: 0.880906
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [477]	valid_0's rmse: 0.880722
# [478]	valid_0's rmse: 0.88053
# [479]	valid_0's rmse: 0.880305
# [480]	valid_0's rmse: 0.880078
# [481]	valid_0's rmse: 0.879789
# [482]	valid_0's rmse: 0.879526
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [483]	valid_0's rmse: 0.879367
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [484]	valid_0's rmse: 0.879231
# [485]	valid_0's rmse: 0.879005
# [486]	valid_0's rmse: 0.878712
# [487]	valid_0's rmse: 0.87846
# [488]	valid_0's rmse: 0.878344
# [489]	valid_0's rmse: 0.87814
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [490]	valid_0's rmse: 0.877932
# [491]	valid_0's rmse: 0.877718
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [492]	valid_0's rmse: 0.877551
# [493]	valid_0's rmse: 0.877406
# [494]	valid_0's rmse: 0.877187
# [495]	valid_0's rmse: 0.876991
# [496]	valid_0's rmse: 0.876797
# [497]	valid_0's rmse: 0.876623
# [498]	valid_0's rmse: 0.876331
# [499]	valid_0's rmse: 0.876073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [500]	valid_0's rmse: 0.87591
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's rmse: 0.87591

# %% [markdown]
# ## Validation

# %%
def avg_corr(pred, raw):
    return sum([pearsonr(pred[:,j], raw[:,j]).statistic for j in [0,1,2,4]])/4

from scipy.interpolate import CubicSpline

Y_train_pred = [None]*3
Y_val_pred = [None]*3
for i in range(3):
    Y_train_pred[i] = []
    Y_val_pred[i] = []
    for j in range(5):
        Y_train_pred[i].append(regs[i][j].predict(X[i], num_iteration=regs[i][j].best_iteration))
        Y_val_pred[i].append(regs[i][j].predict(X_test[i], num_iteration=regs[i][j].best_iteration))
    Y_train_pred[i] = np.hstack([vec.reshape(-1,1) for vec in Y_train_pred[i]])
    Y_val_pred[i] = np.hstack([vec.reshape(-1,1) for vec in Y_val_pred[i]])

Y_train_pred_intped = [
    np.array([CubicSpline(np.arange(len(Y_train_pred[i])), Y_train_pred[i][:,j], bc_type="natural")(np.linspace(0, len(Y_train_pred[i]), 598500)) for j in range(5)]).T for i in range(3)
]
Y_val_pred_intped = [
    np.array([CubicSpline(np.arange(len(Y_val_pred[i])), Y_val_pred[i][:,j], bc_type="natural")(np.linspace(0, len(Y_val_pred[i]), 147500)) for j in range(5)]).T for i in range(3)
]

for i in range(3):
    print("Subject", i+1)
    print("Train Corr: ", [pearsonr(Y_train_pred_intped[i][:,j], Y_raw[i][:,j]).statistic for j in range(5)])
    print("Val Corr: ", [pearsonr(Y_val_pred_intped[i][:,j], Y_test_raw[i][:,j]).statistic for j in range(5)])
    print("Average Train Corr: ", avg_corr(Y_train_pred_intped[i], Y_raw[i]))
    print("Average Val Corr: ", avg_corr(Y_val_pred_intped[i], Y_test_raw[i]))
# Out:
# Subject 1
# Train Corr:  [0.5685715516473693, 0.6255566018537062, 0.5825189661071921, 0.1250747630937245, 0.569385641744906]
# Val Corr:  [0.4927238665089544, 0.6728329092023869, 0.5726682251326455, 0.11177915241952628, 0.5390356694570458]
# Average Train Corr:  0.5865081903382934
# Average Val Corr:  0.5693151675752582
# Subject 2
# Train Corr:  [0.6500887826944182, 0.5731065082399903, 0.622863029860685, 0.16605528171418724, 0.5930799260623879]
# Val Corr:  [0.6815223373234561, 0.6389991972777023, 0.6548042549633128, 0.20043087013898492, 0.6163846578510888]
# Average Train Corr:  0.6097845617143703
# Average Val Corr:  0.6479276118538899
# Subject 3
# Train Corr:  [0.690749512186343, 0.6243501725314453, 0.5952701112197447, 0.34089936326820536, 0.6508935037007537]
# Val Corr:  [0.6555084420728332, 0.6211480063161687, 0.6163294390665547, 0.31290089019168577, 0.6921725756035533]
# Average Train Corr:  0.6403158249095717
# Average Val Corr:  0.6462896157647775

# %% [markdown]
# ## Save

# %%
def avg_corr(pred, raw):
    return sum([pearsonr(pred[:,j], raw[:,j]).statistic for j in [0,1,2,4]])/4

from scipy.interpolate import CubicSpline

Y_pred = [None]*3
for i in range(3):
    Y_pred[i] = []
    for j in range(5):
        Y_pred[i].append(regs[i][j].predict(X_test[i], num_iteration=regs[i][j].best_iteration))
    Y_pred[i] = np.hstack([vec.reshape(-1,1) for vec in Y_pred[i]])

Y_pred_intped = [
    np.array([CubicSpline(np.arange(len(Y_pred[i])), Y_pred[i][:,j], bc_type="natural")(np.linspace(0, len(Y_pred[i]), 147500)) for j in range(5)]).T for i in range(3)
]

for i in range(3):
    print("Subject", i+1)
    print("Val Corr: ", [pearsonr(Y_pred_intped[i][:,j], Y_test_raw[i][:,j]).statistic for j in range(5)])
    print("Average Val Corr: ", avg_corr(Y_pred_intped[i], Y_test_raw[i]))
# Out:
# Subject 1
# Val Corr:  [0.4927238665089544, 0.6728329092023869, 0.5726682251326455, 0.11177915241952628, 0.5390356694570458]
# Average Val Corr:  0.5693151675752582
# Subject 2
# Val Corr:  [0.6815223373234561, 0.6389991972777023, 0.6548042549633128, 0.20043087013898492, 0.6163846578510888]
# Average Val Corr:  0.6479276118538899
# Subject 3
# Val Corr:  [0.6555084420728332, 0.6211480063161687, 0.6163294390665547, 0.31290089019168577, 0.6921725756035533]
# Average Val Corr:  0.6462896157647775

# %%
predictions = np.zeros((3,1), dtype=object)
predictions[0,0] = Y_val_pred_intped[0]
predictions[1,0] = Y_val_pred_intped[1]
predictions[2,0] = Y_val_pred_intped[2]

scipy.io.savemat("predictions.mat", {"predicted_dg": predictions})

# %%
for i in range(3):
    for j in range(5):
        regs[i][j].save_model(f'lgb_subj{i}_finger{j}.txt')

# %% [markdown]
# ## Test saved models

# %%
import lightgbm as lgb
regs = []
for i in range(3):
    regs_subj = []
    for j in range(5):
        regs_subj.append(lgb.Booster(model_file=f'lgb_subj{i}_finger{j}.txt'))
    regs.append(regs_subj)

# %%
def avg_corr(pred, raw):
    return sum([pearsonr(pred[:,j], raw[:,j]).statistic for j in [0,1,2,4]])/4

from scipy.interpolate import CubicSpline

Y_pred = [None]*3
for i in range(3):
    Y_pred[i] = []
    for j in range(5):
        Y_pred[i].append(regs[i][j].predict(X_test[i], num_iteration=regs[i][j].best_iteration))
    Y_pred[i] = np.hstack([vec.reshape(-1,1) for vec in Y_pred[i]])

Y_pred_intped = [
    np.array([CubicSpline(np.arange(len(Y_pred[i])), Y_pred[i][:,j], bc_type="natural")(np.linspace(0, len(Y_pred[i]), 147500)) for j in range(5)]).T for i in range(3)
]

for i in range(3):
    print("Subject", i+1)
    print("Val Corr: ", [pearsonr(Y_pred_intped[i][:,j], Y_test_raw[i][:,j]).statistic for j in range(5)])
    print("Average Val Corr: ", avg_corr(Y_pred_intped[i], Y_test_raw[i]))
# Out:
# Subject 1
# Val Corr:  [0.4927238665089544, 0.6728329092023869, 0.5726682251326455, 0.11177915241952628, 0.5390356694570458]
# Average Val Corr:  0.5693151675752582
# Subject 2
# Val Corr:  [0.6815223373234561, 0.6389991972777023, 0.6548042549633128, 0.20043087013898492, 0.6163846578510888]
# Average Val Corr:  0.6479276118538899
# Subject 3
# Val Corr:  [0.6555084420728332, 0.6211480063161687, 0.6163294390665547, 0.31290089019168577, 0.6921725756035533]
# Average Val Corr:  0.6462896157647775
